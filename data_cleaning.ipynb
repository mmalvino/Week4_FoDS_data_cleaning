# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", 10)
df = pd.read_csv('results.csv')
df
# Out:
#              date    home_team away_team  home_score  away_score  \
# 0      1872-11-30     Scotland   England           0           0
# 1      1873-03-08      England  Scotland           4           2
# 2      1874-03-07     Scotland   England           2           1
# 3      1875-03-06      England  Scotland           2           2
# 4      1876-03-04     Scotland   England           3           0
# ...           ...          ...       ...         ...         ...
# 44929  2023-09-12      Belgium   Estonia           5           0
# 44930  2023-09-12       Sweden   Austria           1           3
# 44931  2023-09-12  Switzerland   Andorra           3           0
# 44932  2023-09-12       Israel   Belarus           1           0
# 44933  2023-09-12      Romania    Kosovo           2           0
#
#                     tournament       city      country  neutral
# 0                     Friendly    Glasgow     Scotland    False
# ...

# %%
df.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
df.tail()
# Out:
#              date    home_team away_team  home_score  away_score  \
# 44929  2023-09-12      Belgium   Estonia           5           0
# 44930  2023-09-12       Sweden   Austria           1           3
# 44931  2023-09-12  Switzerland   Andorra           3           0
# 44932  2023-09-12       Israel   Belarus           1           0
# 44933  2023-09-12      Romania    Kosovo           2           0
#
#                     tournament       city      country  neutral
# 44929  UEFA Euro qualification   Brussels      Belgium    False
# 44930  UEFA Euro qualification  Stockholm       Sweden    False
# 44931  UEFA Euro qualification       Sion  Switzerland    False
# 44932  UEFA Euro qualification   Tel Aviv       Israel    False
# 44933  UEFA Euro qualification  Bucharest      Romania    False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44934 entries, 0 to 44933
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        44934 non-null  object
#  1   home_team   44934 non-null  object
#  2   away_team   44934 non-null  object
#  3   home_score  44934 non-null  int64
#  4   away_score  44934 non-null  int64
#  5   tournament  44934 non-null  object
#  6   city        44934 non-null  object
#  7   country     44934 non-null  object
#  8   neutral     44934 non-null  bool
# dtypes: bool(1), int64(2), object(6)
# memory usage: 2.8+ MB

# %%
df.describe()
# Out:
#          home_score    away_score
# count  44934.000000  44934.000000
# mean       1.739507      1.178284
# std        1.746873      1.393037
# min        0.000000      0.000000
# 25%        1.000000      0.000000
# 50%        1.000000      1.000000
# 75%        2.000000      2.000000
# max       31.000000     21.000000

# %%
df.isnull().sum()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %%
df2 = pd.read_csv('shootouts.csv')
df2
# Out:
#            date      home_team         away_team         winner
# 0    1967-08-22          India            Taiwan         Taiwan
# 1    1971-11-14    South Korea  Vietnam Republic    South Korea
# 2    1972-05-07    South Korea              Iraq           Iraq
# 3    1972-05-17       Thailand       South Korea    South Korea
# 4    1972-05-19       Thailand          Cambodia       Thailand
# ..          ...            ...               ...            ...
# 553  2023-07-04          India            Kuwait          India
# 554  2023-07-09  United States            Canada  United States
# 555  2023-07-12  United States            Panama         Panama
# 556  2023-09-07           Iraq             India           Iraq
# 557  2023-09-10       Thailand              Iraq           Iraq
#
# [558 rows x 4 columns]

# %%
df2.head()
# Out:
#          date    home_team         away_team       winner
# 0  1967-08-22        India            Taiwan       Taiwan
# 1  1971-11-14  South Korea  Vietnam Republic  South Korea
# 2  1972-05-07  South Korea              Iraq         Iraq
# 3  1972-05-17     Thailand       South Korea  South Korea
# 4  1972-05-19     Thailand          Cambodia     Thailand

# %%
df2.isnull().sum()
# Out:
# date         0
# home_team    0
# away_team    0
# winner       0
# dtype: int64

# %%
df_merge = df.merge(df2, left_on='home_team', right_on='home_team')
df_merge = df_merge[0:10]
df = df_merge
df
# Out:
#        date_x home_team away_team_x  home_score  away_score tournament  \
# 0  1872-11-30  Scotland     England           0           0   Friendly
# 1  1874-03-07  Scotland     England           2           1   Friendly
# 2  1876-03-04  Scotland     England           3           0   Friendly
# 3  1876-03-25  Scotland       Wales           4           0   Friendly
# 4  1878-03-02  Scotland     England           7           2   Friendly
# 5  1878-03-23  Scotland       Wales           9           0   Friendly
# 6  1880-03-13  Scotland     England           5           4   Friendly
# 7  1880-03-27  Scotland       Wales           5           1   Friendly
# 8  1882-03-11  Scotland     England           5           1   Friendly
# 9  1882-03-25  Scotland       Wales           5           0   Friendly
#
#       city   country  neutral      date_y away_team_y    winner
# 0  Glasgow  Scotland    False  2020-10-08      Israel  Scotland
# ...

# %%
df.query('home_score > away_score')
# Out:
#        date_x home_team away_team_x  home_score  away_score tournament  \
# 1  1874-03-07  Scotland     England           2           1   Friendly
# 2  1876-03-04  Scotland     England           3           0   Friendly
# 3  1876-03-25  Scotland       Wales           4           0   Friendly
# 4  1878-03-02  Scotland     England           7           2   Friendly
# 5  1878-03-23  Scotland       Wales           9           0   Friendly
# 6  1880-03-13  Scotland     England           5           4   Friendly
# 7  1880-03-27  Scotland       Wales           5           1   Friendly
# 8  1882-03-11  Scotland     England           5           1   Friendly
# 9  1882-03-25  Scotland       Wales           5           0   Friendly
#
#       city   country  neutral      date_y away_team_y    winner
# 1  Glasgow  Scotland    False  2020-10-08      Israel  Scotland
# 2  Glasgow  Scotland    False  2020-10-08      Israel  Scotland
# 3  Glasgow  Scotland    False  2020-10-08      Israel  Scotland
# ...

# %%
np.random.seed(50)
col_name=['home_score','away_score']
mask = np.random.choice([True, False], size=df[col_name].shape)
mask[mask.all(1),-1] = 0
print(mask)
df[col_name]=df[col_name].mask(mask)
df
# Out:
# [[ True False]
#  [False False]
#  [False  True]
#  [ True False]
#  [False  True]
#  [ True False]
#  [False  True]
#  [False  True]
#  [False False]
#  [ True False]]
#        date_x home_team away_team_x  home_score  away_score tournament  \
# 0  1872-11-30  Scotland     England         NaN         0.0   Friendly
# 1  1874-03-07  Scotland     England         2.0         1.0   Friendly
# 2  1876-03-04  Scotland     England         3.0         NaN   Friendly
# 3  1876-03-25  Scotland       Wales         NaN         0.0   Friendly
# 4  1878-03-02  Scotland     England         7.0         NaN   Friendly
# 5  1878-03-23  Scotland       Wales         NaN         0.0   Friendly
# 6  1880-03-13  Scotland     England         5.0         NaN   Friendly
# 7  1880-03-27  Scotland       Wales         5.0         NaN   Friendly
# 8  1882-03-11  Scotland     England         5.0         1.0   Friendly
# 9  1882-03-25  Scotland       Wales         NaN         0.0   Friendly
#
# ...

# %%
df.isnull().sum()
# Out:
# date_x         0
# home_team      0
# away_team_x    0
# home_score     4
# away_score     4
#               ..
# country        0
# neutral        0
# date_y         0
# away_team_y    0
# winner         0
# Length: 12, dtype: int64

# %%
df.rename(columns={'winner': 'victory goes to'})
# Out:
#        date_x home_team away_team_x  home_score  away_score tournament  \
# 0  1872-11-30  Scotland     England         NaN         0.0   Friendly
# 1  1874-03-07  Scotland     England         2.0         1.0   Friendly
# 2  1876-03-04  Scotland     England         3.0         NaN   Friendly
# 3  1876-03-25  Scotland       Wales         NaN         0.0   Friendly
# 4  1878-03-02  Scotland     England         7.0         NaN   Friendly
# 5  1878-03-23  Scotland       Wales         NaN         0.0   Friendly
# 6  1880-03-13  Scotland     England         5.0         NaN   Friendly
# 7  1880-03-27  Scotland       Wales         5.0         NaN   Friendly
# 8  1882-03-11  Scotland     England         5.0         1.0   Friendly
# 9  1882-03-25  Scotland       Wales         NaN         0.0   Friendly
#
#       city   country  neutral      date_y away_team_y victory goes to
# 0  Glasgow  Scotland    False  2020-10-08      Israel        Scotland
# ...

# %%
df.set_index('home_team')
# Out:
#                date_x away_team_x  home_score  away_score tournament     city  \
# home_team
# Scotland   1872-11-30     England         NaN         0.0   Friendly  Glasgow
# Scotland   1874-03-07     England         2.0         1.0   Friendly  Glasgow
# Scotland   1876-03-04     England         3.0         NaN   Friendly  Glasgow
# Scotland   1876-03-25       Wales         NaN         0.0   Friendly  Glasgow
# Scotland   1878-03-02     England         7.0         NaN   Friendly  Glasgow
# Scotland   1878-03-23       Wales         NaN         0.0   Friendly  Glasgow
# Scotland   1880-03-13     England         5.0         NaN   Friendly  Glasgow
# Scotland   1880-03-27       Wales         5.0         NaN   Friendly  Glasgow
# Scotland   1882-03-11     England         5.0         1.0   Friendly  Glasgow
# Scotland   1882-03-25       Wales         NaN         0.0   Friendly  Glasgow
#
#             country  neutral      date_y away_team_y    winner
# home_team
# ...

# %%
df.melt()
# Out:
#     variable       value
# 0     date_x  1872-11-30
# 1     date_x  1874-03-07
# 2     date_x  1876-03-04
# 3     date_x  1876-03-25
# 4     date_x  1878-03-02
# ..       ...         ...
# 115   winner    Scotland
# 116   winner    Scotland
# 117   winner    Scotland
# 118   winner    Scotland
# 119   winner    Scotland
#
# [120 rows x 2 columns]

# %%
df.apply(lambda x: [1, 2], axis=1, result_type='expand')
# Out:
#    0  1
# 0  1  2
# 1  1  2
# 2  1  2
# 3  1  2
# 4  1  2
# 5  1  2
# 6  1  2
# 7  1  2
# 8  1  2
# 9  1  2

# %%
df.dropna(how='all')
# Out:
#        date_x home_team away_team_x  home_score  away_score tournament  \
# 0  1872-11-30  Scotland     England         NaN         0.0   Friendly
# 1  1874-03-07  Scotland     England         2.0         1.0   Friendly
# 2  1876-03-04  Scotland     England         3.0         NaN   Friendly
# 3  1876-03-25  Scotland       Wales         NaN         0.0   Friendly
# 4  1878-03-02  Scotland     England         7.0         NaN   Friendly
# 5  1878-03-23  Scotland       Wales         NaN         0.0   Friendly
# 6  1880-03-13  Scotland     England         5.0         NaN   Friendly
# 7  1880-03-27  Scotland       Wales         5.0         NaN   Friendly
# 8  1882-03-11  Scotland     England         5.0         1.0   Friendly
# 9  1882-03-25  Scotland       Wales         NaN         0.0   Friendly
#
#       city   country  neutral      date_y away_team_y    winner
# 0  Glasgow  Scotland    False  2020-10-08      Israel  Scotland
# ...

# %%
df.fillna(0)
# Out:
#        date_x home_team away_team_x  home_score  away_score tournament  \
# 0  1872-11-30  Scotland     England         0.0         0.0   Friendly
# 1  1874-03-07  Scotland     England         2.0         1.0   Friendly
# 2  1876-03-04  Scotland     England         3.0         0.0   Friendly
# 3  1876-03-25  Scotland       Wales         0.0         0.0   Friendly
# 4  1878-03-02  Scotland     England         7.0         0.0   Friendly
# 5  1878-03-23  Scotland       Wales         0.0         0.0   Friendly
# 6  1880-03-13  Scotland     England         5.0         0.0   Friendly
# 7  1880-03-27  Scotland       Wales         5.0         0.0   Friendly
# 8  1882-03-11  Scotland     England         5.0         1.0   Friendly
# 9  1882-03-25  Scotland       Wales         0.0         0.0   Friendly
#
#       city   country  neutral      date_y away_team_y    winner
# 0  Glasgow  Scotland    False  2020-10-08      Israel  Scotland
# ...

# %%
df.groupby(['tournament']).mean()
# Out:
# <ipython-input-126-f33ffb0c1808>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['tournament']).mean()
#             home_score  away_score  neutral
# tournament
# Friendly           4.5    0.333333      0.0

# %%
df.agg("mean", axis="columns")
# Out:
# <ipython-input-127-41a31b8a6513>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.agg("mean", axis="columns")
# Series([], dtype: float64)
